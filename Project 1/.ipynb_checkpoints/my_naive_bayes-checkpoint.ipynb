# %%
#import required Packages
import sys
from collections import Counter
import os
import re
from math import log
import string
import numpy as np
from itertools import chain
import random
def main():  
   readFile = 'amazon_cells_labelled.txt'  

   if not os.path.isfile(readFile):
       print("File path {} does not exist. Exiting...".format(readFile))
       sys.exit()

   bag_of_words = {}
   vocubulary = {}
   positive_lines=0
   with open(readFile) as fp:
       #print(getVocubulary(fp))
       count = 0
       positive_lines=0
       negative_lines=0 
       positive_class=[]
       for line in fp:
           words_in_line = line.split()
           #positiveClass(line)
            #negativeClass(line)
#            if(words_in_line[-1]=='1'):
#                 positive_class.append(line)
#                 positive_lines+=1
                
#            elif(words_in_line[-1]=='0'):
#                 negative_class.append(line)
#                 negative_lines+=1    
                #count += 1
           #print("line {} : {}".format(count, line))
            
            #record_word_cnt(line.strip().split(' '), bag_of_words)
        count += 1
   #sorted_words = order_bag_of_words(bag_of_words, desc=True)
   #print("Most frequent 10 words {}".format(sorted_words[:10]))
            
#        print("Positive Lines",positive_lines)
#        print("Negative Lines",negative_lines)
   #print(positive_class)          


if __name__ == '__main__':  
   main()
# Out:
# line 0 : So there is no way for me to plug it in here in the US unless I go by a converter.	0
#
# line 1 : Good case, Excellent value.	1
#
# line 2 : Great for the jawbone.	1
#
# line 3 : Tied to charger for conversations lasting more than 45 minutes.MAJOR PROBLEMS!!	0
#
# line 4 : The mic is great.	1
#
# line 5 : I have to jiggle the plug to get it to line up right to get decent volume.	0
#
# line 6 : If you have several dozen or several hundred contacts, then imagine the fun of sending each of them one by one.	0
#
# line 7 : If you are Razr owner...you must have this!	1
#
# line 8 : Needless to say, I wasted my money.	0
#
# line 9 : What a waste of money and time!.	0
#
# line 10 : And the sound quality is great.	1
#
# line 11 : He was very impressed when going from the original battery to the extended battery.	1
#
# line 12 : If the two were seperated by a mere 5+ ft I started to notice excessive static and garbled sound from the headset.	0
#
# line 13 : Very good quality though	1
#
# line 14 : The design is very odd, as the ear "clip" is not very comfortable at all.	0
#
# line 15 : Highly recommend for any one who has a blue tooth phone.	1
#
# line 16 : I advise EVERYONE DO NOT BE FOOLED!	0
#
# line 17 : So Far So Good!.	1
#
# line 18 : Works great!.	1
#
# line 19 : It clicks into place in a way that makes you wonder how long that mechanism would last.	0
#
# line 20 : I went on Motorola's website and followed all directions, but could not get it to pair again.	0
#
# line 21 : I bought this to use with my Kindle Fire and absolutely loved it!	1
#
# line 22 : The commercials are the most misleading.	0
#
# line 23 : I have yet to run this new battery below two bars and that's three days without charging.	1
#
# line 24 : I bought it for my mother and she had a problem with the battery.	0
#
# line 25 : Great Pocket PC / phone combination.	1
#
# line 26 : I've owned this phone for 7 months now and can say that it's the best mobile phone I've had.	1
#
# line 27 : I didn't think that the instructions provided were helpful to me.	0
#
# line 28 : People couldnt hear me talk and I had to pull out the earphone and talk on the phone.	0
#
# line 29 : Doesn't hold charge.	0
#
# line 30 : This is a simple little phone to use, but the breakage is unacceptible.	0
#
# line 31 : This product is ideal for people like me whose ears are very sensitive.	1
#
# line 32 : It is unusable in a moving car at freeway speed.	0
#
# line 33 : I have two more years left in this contract and I hate this phone.	0
#
# line 34 : Car charger as well as AC charger are included to make sure you never run out of juice.Highy recommended	1
#
# line 35 : You need at least 3 mins to get to your phone book from the time you first turn on the phone.Battery life is short.	0
#
# line 36 : It has kept up very well.	1
#
# line 37 : Poor Talk Time Performance.	0
#
# line 38 : The case is great and works fine with the 680.	1
#
# line 39 : worthless product.	0
#
# line 40 : It has a great camera thats 2MP, and the pics are nice and clear with great picture quality.	1
#
# line 41 : I was not impressed by this product.	0
#
# line 42 : Nice headset priced right.	1
#
# line 43 : I only hear garbage for audio.	0
#
# line 44 : Excellent bluetooth headset.	1
#
# line 45 : It has all the features I want	1
#
# line 46 : Who in their right mind is gonna buy this battery?.	0
#
# line 47 : AFTER ARGUING WITH VERIZON REGARDING THE DROPPED CALLS WE RETURNED THE PHONES AFTER TWO DAYS.	0
#
# line 48 : This case seems well made.	1
#
# line 49 : Disappointed with battery.	0
#
# line 50 : Not loud enough and doesn't turn on like it should.	0
#
# line 51 : good protection and does not make phone too bulky.	1
#
# line 52 : A usable keyboard actually turns a PDA into a real-world useful machine instead of just a neat gadget.	1
#
# line 53 : This phone is pretty sturdy and I've never had any large problems with it.	1
#
# line 54 : I love this thing!	1
#
# line 55 : Everything about it is fine and reasonable for the price i.e.	1
#
# line 56 : VERY DISAPPOINTED.	0
#
# line 57 : I even dropped this phone into a stream and it was submerged for 15 seconds and it still works great!	1
#
# line 58 : I have been very happy with the 510 and have had NO complaints from any one regarding my sound quality on their end.	1
#
# line 59 : The buttons for on and off are bad.	0
#
# line 60 : Essentially you can forget Microsoft's tech support.	0
#
# line 61 : I really recommend this faceplates since it looks very nice, elegant and cool.	1
#
# line 62 : These headphones were a great find - and I think they are perhaps the best purchase I've made in the last several years - seriously.	1
#
# line 63 : Buy a different phone - but not this.	0
#
# line 64 : You have to hold the phone at a particular angle for the other party to hear you clearly.	0
#
# line 65 : The one big drawback of the MP3 player is that the buttons on the phone's front cover that let you pause and skip songs lock out after a few seconds.	0
#
# line 66 : A week later after I activated it, it suddenly died.	0
#
# line 67 : It feels more comfortable than most headsets because I wear glasses and that gets in the way sometimes.	1
#
# line 68 : Great for iPODs too.	1
#
# line 69 : This device is great in several situations:1.)	1
#
# line 70 : Mic Doesn't work.	0
#
# line 71 : Even in my BMW 3 series which is fairly quiet, I have trouble hearing what the other person is saying.	0
#
# line 72 : Great choice!	1
#
# line 73 : Nice docking station for home or work.	1
#
# line 74 : This is a beautiful phone.	1
#
# line 75 : Love this product.	1
#
# line 76 : Do Not Buy for D807...wrongly advertised for D807.	0
#
# line 77 : This is a great little item.	1
#
# line 78 : I love this phone , It is very handy and has a lot of features .	1
#
# line 79 : I purchased this and within 2 days it was no longer working!!!!!!!!!	0
#
# line 80 : I wear it everyday and it holds up very well.	1
#
# line 81 : Not a good bargain.	0
#
# line 82 : Well packaged, arrived on time, and works as intended.	1
#
# line 83 : The battery runs down quickly.	0
#
# line 84 : This item worked great, but it broke after 6 months of use.	0
#
# line 85 : The headsets are easy to use and everyone loves them.	1
#
# line 86 : This phone works great.	1
#
# line 87 : The construction of the headsets is poor.	0
#
# line 88 : Product was excellent and works better than the verizon one and Boy was it cheaper!	1
#
# line 89 : The phone loads super!	1
#
# line 90 : For a product that costs as much as this one does, I expect it to work far better and with greater ease than this thing does.	0
#
# line 91 : Made very sturdy.	1
#
# line 92 : Worked great!.	1
#
# line 93 : The ear buds only play music in one ear.	0
#
# line 94 : Dont waste your money...	0
#
# line 95 : Will order from them again!	1
#
# line 96 : If you plan to use this in a car forget about it.	0
#
# line 97 : I found this product to be waaay too big.	0
#
# line 98 : Best I've found so far .... I've tried 2 other bluetooths and this one has the best quality (for both me and the listener) as well as ease of using.	1
#
# line 99 : I'm very disappointed with my decision.	0
#
# line 100 : Integrated seamlessly with the Motorola RAZR phone.	1
#
# line 101 : Buyer Beware, you could flush money right down the toilet.	0
#
# line 102 : Definitely a bargain.	1
#
# line 103 : The price was very good and with the free shipping and all it was a good purchase.	1
#
# line 104 : I received my supposedly new motorola 375 and apparently there was not a match between the phone and the charger.	0
#
# line 105 : Pros:-Good camera - very nice pictures , also has cool styles like black and white, and more.	1
#
# line 106 : That's a huge design flaw (unless I'm not using it correctly, which I don't think is the case).	0
#
# line 107 : I love my 350 headset.. My Jabra350 bluetooth headset is great, the reception is very good and the ear piece is a comfortable fit.	1
#
# line 108 : The camera, although rated at an impressive 1.3 megapixels, renders images that fall well below expectations of such a relatively high resolution.	0
#
# line 109 : I purcashed this for the car charger and it does not work.	0
#
# line 110 : Sound quality on both end is excellent, I use headset to call my wife and ask my wife to use headset to call me !2.	1
#
# line 111 : This phone is slim and light and the display is beautiful.	1
#
# line 112 : its a little geeky but i think thats its sex on toast and it rocks and oozes sex right down to its battery embedded sleek stylish leather case.	1
#
# line 113 : Great product, fast shipping!.	1
#
# line 114 : Absolutely great.	1
#
# line 115 : The keyboard is a nice compromise between a full QWERTY and the basic cell phone number keypad.	1
#
# line 116 : i got this phone around the end of may and i'm completely unhappy with it.	0
#
# line 117 : It is very comfortable on the ear.	1
#
# line 118 : It has been a winner for us.	1
#
# line 119 : )Setup couldn't have been simpler.	1
#
# line 120 : I've tried several different earpieces for my cell phone and this Jabra one is the first one I've found that fits my ear comfortably.	1
#
# line 121 : Could not get strong enough signal.	0
#
# line 122 : Iam very pleased with my purchase.	1
#
# line 123 : Bad Quality.	0
#
# line 124 : Gets the job done.	1
#
# line 125 : Great audio!.	1
#
# line 126 : Basically the service was very bad.	0
#
# line 127 : it did not work in my cell phone plug i am very up set with the charger!.	0
#
# line 128 : I've only had my bluetooth for a few weeks, but I really like it.	1
#
# line 129 : The BT headset was such a disapoinment.	0
#
# line 130 : It is so small and you don't even realize that it is there after a while of getting used to it.	1
#
# line 131 : The accompanied software is almost brilliant.	1
#
# line 132 : Headset works great & was packaged nicely to avoid any damage.	1
#
# line 133 : !I definitly recommend!!	1
#
# line 134 : Buyer--Be Very Careful!!!!!.	0
#
# line 135 : The majority of the Logitech earbud headsets failed.	0
#
# line 136 : Very good stuff for the price.	1
#
# line 137 : My headset works just peachy-keen.	1
#
# line 138 : In my house I was getting dropped coverage upstairs and no coverage in my basement.	0
#
# line 139 : Voice recognition is tremendous!	1
#
# line 140 : What a waste.	0
#
# line 141 : During several different 2 minute calls, I experienced 5 drops and it was in an area that had 5 bars.	0
#
# line 142 : I was not happy with this item.	0
#
# line 143 : very disappointed.	0
#
# line 144 : The phone takes FOREVER to charge like 2 to 5 hours literally.	0
#
# line 145 : I got this phone on reccomendation from a relative and I'm glad I did.	1
#
# line 146 : What a waste of time!	0
#
# line 147 : Its reception is very very poor.	0
#
# line 148 : Items stated as included from the description ARE NOT INCLUDED.	0
#
# line 149 : After 3 months, screen just went black all of a sudden.	0
#
# line 150 : I Was Hoping for More.	0
#
# line 151 : Audio Quality is poor, very poor.	0
#
# line 152 : I had absolutely no problem with this headset linking to my 8530 Blackberry Curve!	1
#
# line 153 : I know that sounds funny, but to me it seemed like sketchy technology that wouldn't work well.Well, this one works great.	1
#
# line 154 : I've bought $5 wired headphones that sound better than these.	0
#
# line 155 : This phone is very fast with sending any kind of messages and web browsing is significantly faster than previous phones i have used.	1
#
# line 156 : Nice quality build, unlike some cheap s*** out there.	1
#
# line 157 : This item is fantastic and works perfectly!	1
#
# line 158 : And I just love the colors!	1
#
# line 159 : W810i is just SUPERB.	1
#
# line 160 : All I can do is whine on the Internet, so here it goes.The more I use the thing the less I like it.	0
#
# line 161 : Great charger.	1
#
# line 162 : This is essentially a communications tool that does not communicate.	0
#
# line 163 : Works like a charm; it work the same as the one I got with the phone.	1
#
# line 164 : I still maintain that monkeys shouldn't make headphones, we just obviously don't share enough DNA to copy the design over to humans.	0
#
# line 165 : Great Value.	1
#
# line 166 : Doesn't work at all.. I bougth it for my L7c and its not working.	0
#
# line 167 : The look of it is very sharp and the screen is nice and clear, with great graphics.	1
#
# line 168 : doesn't last long.	0
#
# line 169 : One thing I hate is the mode set button at the side.	0
#
# line 170 : EXCELLENT SERVICE!!!!!!!!.	1
#
# line 171 : Thank you for wasting my money.	0
#
# line 172 : How can that be?The audio quality is poor.	0
#
# line 173 : The iGo chargers and tips are really great.	1
#
# line 174 : The file browser offers all the options that one needs.Handsfree is great.	1
#
# line 175 : Superb Phone on a Great Network.	1
#
# line 176 : I connected my wife's bluetooth,(Motorola HS850) to my phone and it worked like a charm whether the phone was in my pocket or the case.	1
#
# line 177 : I put the latest OS on it (v1.15g), and it now likes to slow to a crawl and lock up every once in a while.	0
#
# line 178 : It only recognizes the Phone as its storage device.	0
#
# line 179 : If you like a loud buzzing to override all your conversations, then this phone is for you!	0
#
# line 180 : Don't buy this product.	0
#
# line 181 : I've had this bluetoooth headset for some time now and still not comfortable with the way it fits on the ear.	0
#
# line 182 : The sound quality is good and functionality is awesome.	1
#
# line 183 : I have this phone and it is a thorn in my side, I really abhor it.	0
#
# line 184 : I recently had problems where I could not stay connected for more than 10 minutes before being disconnected.	0
#
# line 185 : Incredible!.	1
#
# line 186 : Design Flaw?.	0
#
# line 187 : Great phone!.	1
#
# line 188 : Waste of 13 bucks.	0
#
# line 189 : But when I check voice mail at night, the keypad backlight turns off a few seconds into the first message, and then I'm lost.	0
#
# line 190 : The replacement died in a few weeks.	0
#
# line 191 : Any ring tone..Overall good phone to buy..	1
#
# line 192 : Lately they have been extremely nice and helpful on the phone.	1
#
# line 193 : I have had problems wit hit dropping signal and more.	0
#
# line 194 : Not impressed.	0
#
# line 195 : Light weight, I hardly notice it is there.	1
#
# line 196 : You'll love how thin it is.	1
#
# line 197 : Bad Choice.	0
#
# line 198 : The pleather case doesn't fit.	0
#
# line 199 : useless phone, simply deaf.	0
#
# line 200 : The color is even prettier than I thought it would be, and the graphics are incredibly sharp.	1
#
# line 201 : All in all I think it was a good investment.	1
#
# line 202 : It makes very strange ticking noises before it ends the call.	0
#
# line 203 : The best electronics of the available FM Transmitters.	1
#
# line 204 : Battery lasts only a few hours.	0
#
# line 205 : great headset, very impressed - H500.	1
#
# line 206 : The "1.2" mega pixel camera, being a part of a phone, is reasonably good7.	1
#
# line 207 : I've had this for nearly 2 years and it has worked great for me.	1
#
# line 208 : Good transmit audio.	1
#
# line 209 : We are sending it back.	0
#
# line 210 : I did not bother contacting the company for few dollar product but I learned the lesson that I should not have bought this form online anyway.	0
#
# line 211 : If you hate earbugs, avoid this phone by all means.	0
#
# line 212 : Great price also!	1
#
# line 213 : The range is very decent, I've been able to roam around my house with the phone in the living room with no reception/sound quality issues.	1
#
# line 214 : fast service.	1
#
# line 215 : I would highly recommend this.	1
#
# line 216 : I would recommend this.	1
#
# line 217 : I also didn't like the "on" button, it felt like it would crack with use.	0
#
# line 218 : WORST PHONE EVER.	0
#
# line 219 : I'm still infatuated with this phone.	1
#
# line 220 : Freezes frequently4.	0
#
# line 221 : It's kind of embarrassing to use because of how it looks and mostly it's embarrassing how child-like the company is.	0
#
# line 222 : Simple, lightweight and great fit.	1
#
# line 223 : All in all, I'd expected a better consumer experience from Motorola.	0
#
# line 224 : There's a horrible tick sound in the background on all my calls that I have never experienced before.	0
#
# line 225 : These are certainly very comfortable and functionality is decent.	1
#
# line 226 : I usually don't like headbands but this one is very lightweight & doesn't mess up my hair.	1
#
# line 227 : I'm a bit disappointed.	0
#
# line 228 : I have had this phone for over a year now, and I will tell you, its not that great.	0
#
# line 229 : I ordered this for sony Ericsson W810i but I think it only worked once (thats when I first used it).	0
#
# line 230 : The battery is completely useless to me.	0
#
# line 231 : What a big waste of time.	0
#
# line 232 : Don't waste your $$$ on this one.	0
#
# line 233 : Great sound and service.	1
#
# line 234 : Really pleased with this product so far.	1
#
# line 235 : One of my favorite purchases ever.	1
#
# line 236 : best bluetooth on the market.	1
#
# line 237 : Authentic leather with nice shine and comfort .I recommend you this case !!	1
#
# line 238 : I was very excited to get this headset because I thought it was really cute.	1
#
# line 239 : Do not make the same mistake as me.	0
#
# line 240 : Big Disappointment with calendar sync.	0
#
# line 241 : the phone was unusable and was not new.	0
#
# line 242 : Worst Customer Service Ever.	0
#
# line 243 : No additional ear gels provided, and no instructions whatsoever.	0
#
# line 244 : It defeats the purpose of a bluetooth headset.	0
#
# line 245 : Worth every penny.	1
#
# line 246 : Excellent wallet type phone case.	1
#
# line 247 : Nice headphones for the price and they work great!	1
#
# line 248 : Internet is excrutiatingly slow.	0
#
# line 249 : It is very comfortable to wear as well, which is probably the most important aspect about using a case.	1
#
# line 250 : It's fits like a glove and is strong, secure, and durable.	1
#
# line 251 : O my gosh the best phone I have ever had.	1
#
# line 252 : It's very attractive and appears to be of good quality.	1
#
# line 253 : I love all the features and form factor.	1
#
# line 254 : This product had a strong rubber/petroleum smell that was unbearable after a while and caused me to return it	0
#
# line 255 : poor quality and service.	0
#
# line 256 : The cable looks so thin and flimsy, it is scary.	0
#
# line 257 : Great Earpiece.	1
#
# line 258 : Excellent hands free tool.	1
#
# line 259 : Great for using with your home stereo.	1
#
# line 260 : Good product - incredible value.	1
#
# line 261 : Only had this a month but it's worked flawlessly so far.	1
#
# line 262 : Works great.	1
#
# line 263 : Absolutel junk.	0
#
# line 264 : THAT one didn't work either.	0
#
# line 265 : Battery life is real good.	1
#
# line 266 : Returned 8 hours later.	0
#
# line 267 : It's a great item.	1
#
# line 268 : Don't waste your money!.	0
#
# line 269 : Love this headset!	1
#
# line 270 : Not only will it drain your player, but may also potentially fry it.	0
#
# line 271 : Worked perfectly!	1
#
# line 272 : Unreliable - I'm giving up.	0
#
# line 273 : I gave it 5 stars because of the sound quality.	1
#
# line 274 : Avoid this one if you can.	0
#
# line 275 : Reversible plug works great.	1
#
# line 276 : I wasted my little money with this earpiece.	0
#
# line 277 : Very good phone.	1
#
# line 278 : Best of all is the rotating feature, very helpful.	1
#
# line 279 : Comfort for our whole family.	1
#
# line 280 : Good product, good seller.	1
#
# line 281 : I love this bluetooth!	1
#
# line 282 : First of all, it doesn't wear well.	0
#
# line 283 : I am very impressed with this headset from Plantronics.	1
#
# line 284 : I got it because it was so small and adorable.	1
#
# line 285 : Great phone!.	1
#
# line 286 : I wouldn't recommend buying this product.	0
#
# line 287 : Piece of Junk.	0
#
# line 288 : Poorly contstruct hinge.	0
#
# line 289 : This item is great, installed it, let it charged up overnite and it has been working good every since with no problems	1
#
# line 290 : Great Phone.	1
#
# line 291 : Don't buy it.	0
#
# line 292 : Excellent Phone.	1
#
# line 293 : DO NOT PURCHASE THIS PHONE.	0
#
# line 294 : The voice recognition thru the handset is excellent.	1
#
# line 295 : This is hands down the best phone I've ever had.	1
#
# line 296 : Works great, when my cat attacked the phone he scratched the protective strip instead of destroying the screen.	1
#
# line 297 : This one works and was priced right.	1
#
# line 298 : Customer service was terrible.	0
#
# line 299 : Battery life still not long enough in Motorola Razor V3i.	0
#
# line 300 : Sending it back.	0
#
# line 301 : Now I know that I made a wise decision.	1
#
# line 302 : Someone shouldve invented this sooner.	1
#
# line 303 : Good price.	1
#
# line 304 : Everything worked on the first try.The device was certainly engineered in a clever way and the construction feels good.	1
#
# line 305 : I received it quickly and it works great!!	1
#
# line 306 : Has been working great.	1
#
# line 307 : As many people complained, I found this headset's microphone was very weak.	0
#
# line 308 : My 5-year old Nokia 2160 from Tracfone holds the charge a lot better than this.	0
#
# line 309 : They do not care about the consumer one bit.	0
#
# line 310 : This is a good battery, and it got here really fast.	1
#
# line 311 : The instruction manual is lacking.	0
#
# line 312 : Also its slim enough to fit into my alarm clock docking station without removing the case.	1
#
# line 313 : Phone now holds charge like it did when it was new.	1
#
# line 314 : The battery is unreliable as well as the service use antena.	0
#
# line 315 : It's uncomfortable and the sound quality is quite poor compared with the phone (Razr) or with my previous wired headset (that plugged into an LG).	0
#
# line 316 : We have gotten a lot of compliments on it.	1
#
# line 317 : This is definitely a must have if your state does not allow cell phone usage while driving.	1
#
# line 318 : I want my money back.	0
#
# line 319 : I love this device.	1
#
# line 320 : I am also very happy with the price.	1
#
# line 321 : I ordered this product first and was unhappy with it immediately.	0
#
# line 322 : The Ngage is still lacking in earbuds.	0
#
# line 323 : I was able to do voice dialing in the car with no problem.	1
#
# line 324 : I have 2-3 bars on my cell phone when I am home, but you cant not hear anything.	0
#
# line 325 : good item, low price.	1
#
# line 326 : However-the riingtones are not the best, and neither are the games.	0
#
# line 327 : The plug did not work very well.	0
#
# line 328 : AMAZON SUCKS.	0
#
# line 329 : Rip off---- Over charge shipping.	0
#
# line 330 : VERY comfortable.	1
#
# line 331 : The battery is working well as a replacement for the original that came with the phone over 2 years ago.	1
#
# line 332 : The reception is excellent!	1
#
# line 333 : It fits comfortably in either ear, the sound is clear and loud, and the charge lasts a couple of days.	1
#
# line 334 : very clear, quality sound and you don't have to mess with the sound on your iPod since you have the sound buttons on the headset.	1
#
# line 335 : 1. long lasting battery (you don't have to recharge it as frequentyly as some of the flip phones)2.	0
#
# line 336 : Obviously there is a problem with the adhesive.	0
#
# line 337 : Very disappointing.	0
#
# line 338 : It was an inexpensive piece, but I would still have expected better quality.	0
#
# line 339 : It is practically useless and did not add any kind of boost to my reception after I bought it.	0
#
# line 340 : Excellent sound quality.	1
#
# line 341 : Was not happy.	0
#
# line 342 : A PIECE OF JUNK THAT BROKE AFTER BEING ON MY PHONE FOR 2 DAYS!!!	0
#
# line 343 : New Battery works great in phone.	1
#
# line 344 : Worst customer service.	0
#
# line 345 : I've dropped my phone more times than I can say, even on concrete and my phone is still great (knock on wood!).	1
#
# line 346 : Reception is terrible and full of static.	0
#
# line 347 : Good audio quality.	1
#
# line 348 : This little device has transformed my organizational capability and made my life a whole lot easier.	1
#
# line 349 : I was sitting in my vehicle, with the cradle on my belt, and the headset lost signal.	0
#
# line 350 : Were JERKS on the phone.	0
#
# line 351 : Works like a charm.. Works as advertised.	1
#
# line 352 : Comfortable, Nice Range, Good Battery Life.	1
#
# line 353 : Their network coverage in Los Angeles is horrible.	0
#
# line 354 : Excellent starter wireless headset.	0
#
# line 355 : The loudspeaker option is great, the bumpers with the lights is very ... appealing.	0
#
# line 356 : The only thing that I think could improve is the sound leaks out from the headset.	0
#
# line 357 : First off the reception sucks, I have never had more than 2 bars, ever.	0
#
# line 358 : The phone gets EXTREMELY HOT!	0
#
# line 359 : The microphone also works well, but (according to people I have called) it applifies everything.	1
#
# line 360 : Nice design and quality.	1
#
# line 361 : Also, if your phone is dropped, this case is not going to save it, specially when dropped face down.	0
#
# line 362 : It is light, easy to use, and has very clear reception and transmission.	1
#
# line 363 : bad fit, way too big.	0
#
# line 364 : It definitely was not as good as my S11.	1
#
# line 365 : awesome device.	1
#
# line 366 : Waste of money.	0
#
# line 367 : I had ordered a motorola data cable, got a very well finished and working product.	1
#
# line 368 : Love This Phone.	1
#
# line 369 : I was looking for this headset for a long time and now that I've got it I couldn't be happier.	1
#
# line 370 : I'll be drivng along, and my headset starts ringing for no reason.	0
#
# line 371 : Display is excellent and camera is as good as any from that year.	1
#
# line 372 : Battery life is also great!	1
#
# line 373 : The worst phone I've ever had.... Only had it for a few months.	0
#
# line 374 : Not a good item.. It worked for a while then started having problems in my auto reverse tape player.	0
#
# line 375 : This is so embarassing and also my ears hurt if I try to push the ear plug into my ear.	0
#
# line 376 : Protects the phone on all sides.	1
#
# line 377 : This is a VERY average phone with bad battery life that operates on a weak network.	0
#
# line 378 : Clear Skype Calls, Long Battery Life, Long Range.	1
#
# line 379 : Soyo technology sucks.	0
#
# line 380 : Great Hands Free Device.	1
#
# line 381 : you can even take self portraits with the outside (exterior) display, very cool.	1
#
# line 382 : Same problem as others have mentioned.	0
#
# line 383 : After trying many many handsfree gadgets this is the one that finally works well.	1
#
# line 384 : Magical Help.	1
#
# line 385 : The worst piece of crap ever along with the Verizon customer service.	0
#
# line 386 : Poor sound quality.	0
#
# line 387 : The best phone in market :).	1
#
# line 388 : It worked very well.	1
#
# line 389 : The company shipped my product very promptly and it works well.	1
#
# line 390 : Exactly what I wanted.	1
#
# line 391 : The picture resolution is far below what other comparably-priced phones are offering today.	0
#
# line 392 : This is a great deal.	1
#
# line 393 : Excellent product, I am very satisfied with the purchase.	1
#
# line 394 : I highly recommend these and encourage people to give them a try.	1
#
# line 395 : Better than you'd expect.	1
#
# line 396 : Using all earpieces, left or right, this thing will not stay on my ear.	0
#
# line 397 : Great product and price.	1
#
# line 398 : Sounds good reasonably priced and effective, Its that simple !	1
#
# line 399 : Still Waiting...... I'm sure this item would work well.. if I ever recieve it!	0
#
# line 400 : what a disappointment	0
#
# line 401 : Very prompt service.	1
#
# line 402 : Excellent product for the price.	1
#
# line 403 : Very pleased with this headset.	1
#
# line 404 : don't waste your money and time.	0
#
# line 405 : I especially love the long battery life.	1
#
# line 406 : It's so stupid to have to keep buying new chargers, car chargers, cradles, headphones and car kits every time a new phone comes out.	0
#
# line 407 : Works great.	1
#
# line 408 : Plantronics Bluetooth Excelent Buy.	1
#
# line 409 : I came over from Verizon because cingulair has nicer cell phones.... the first thing I noticed was the really bad service.	0
#
# line 410 : I'll be looking for a new earpiece.	0
#
# line 411 : I highly recommend this device to everyone!	1
#
# line 412 : Jawbone Era is awesome too!	1
#
# line 413 : We received a WHITE colored battery that goes DEAD after a couple hoursTHe original used to last a week - but still lasts longer than thereplacement	0
#
# line 414 : After a year the battery went completely dead on my headset.	0
#
# line 415 : I have used several phone in two years, but this one is the best.	1
#
# line 416 : An Awesome New Look For Fall 2000!.	1
#
# line 417 : This is the first phone I've had that has been so cheaply made.	0
#
# line 418 : Att is not clear, sound is very distorted and you have to yell when you talk.	0
#
# line 419 : The plastic breaks really easy on this clip.	0
#
# line 420 : Price is good too.	1
#
# line 421 : Don't make the same mistake I did.	0
#
# line 422 : Oh and I forgot to also mention the weird color effect it has on your phone.	0
#
# line 423 : I'm using it with an iriver SPINN (with case) and it fits fine.	1
#
# line 424 : Also the area where my unit broke).- I'm not too fond of the magnetic strap.	0
#
# line 425 : Overall, I am psyched to have a phone which has all my appointments and contacts in and gets great reception.	1
#
# line 426 : every thing on phone work perfectly, she like it.	1
#
# line 427 : Another note about this phone's appearance is that it really looks rather bland, especially in the all black model.	0
#
# line 428 : IT'S REALLY EASY.	1
#
# line 429 : My Sanyo has survived dozens of drops on blacktop without ill effect.	1
#
# line 430 : Fantastic earphones.	1
#
# line 431 : It finds my cell phone right away when I enter the car.	1
#
# line 432 : Low Quality.	0
#
# line 433 : I highly recommend this modest priced cellular phone.	1
#
# line 434 : But it does get better reception and clarity than any phone I've had before.	1
#
# line 435 : Warning - Stay away.	0
#
# line 436 : I wish I could return the unit and get back my money.	0
#
# line 437 : Awsome Device Works Great!!.	1
#
# line 438 : I used to talk on it for 1 - 1 1/2 hours and the battery would be literally drained and dying.	0
#
# line 439 : If you don't find it, too bad, as again the unit comes with one earpad only.I would not recommend this to anyone.	0
#
# line 440 : Very Displeased.	0
#
# line 441 : I might have gotten a defect, but I would not risk buying it again because of the built quality alone.	0
#
# line 442 : They made this case too small and is very difficult to install.	0
#
# line 443 : Restored my phone to like new performance.	1
#
# line 444 : I would recommend purchasing the Jabra JX-10 series 2 which works flawlessly with my Moto Q, go figure.	1
#
# line 445 : I searched the Internet, and found this one to be the best value.	1
#
# line 446 : Does not fit.	0
#
# line 447 : Very happy with this product.	1
#
# line 448 : The screen size is big, key pad lit well enough, and the camera quality is excellent for a camera phone.	1
#
# line 449 : There's really nothing bad I can say about this headset.	0
#
# line 450 : i'm glad i found this product on amazon it is hard to find, it wasn't high priced.	1
#
# line 451 : Portable and it works.	1
#
# line 452 : My colleague & I now get great reception.A little expensive, but performance is great.	1
#
# line 453 : I even fully charged it before I went to bed and turned off blue tooth and wi-fi and noticed that it only had 20 % left in the morning.	0
#
# line 454 : I've also had problems with the phone reading the memory card in which I always turn it on and then off again.	0
#
# line 455 : Not good when wearing a hat or sunglasses.	0
#
# line 456 : Timely shipment and quality product.	1
#
# line 457 : Nice solid keyboard.	1
#
# line 458 : Very well made and fits my Surefire GX2 perfectly.	1
#
# line 459 : Horrible phone.	0
#
# line 460 : BT50 battery junk!.	0
#
# line 461 : We would recommend these to others.	1
#
# line 462 : Cant get the software to work with my computer.	0
#
# line 463 : Disappointed!.	0
#
# line 464 : poor voice clarity.	0
#
# line 465 : The battery works great!	1
#
# line 466 : No buyers remorse on this one!.	0
#
# line 467 : Very disappointed in AccessoryOne.	0
#
# line 468 : I find this inexcusable and so will probably be returning this phone and perhaps changing carriers.	0
#
# line 469 : Looks great and is strong."	1
#
# line 470 : I have had TMobile service for 2 or 3 years now, and I am pretty happy with it.	1
#
# line 471 : The update procedure is difficult and cumbersome.	0
#
# line 472 : Disappointment.. I hate anything that goes in my ear.	0
#
# line 473 : Great software for Motorolas.	1
#
# line 474 : The delivery was on time.	1
#
# line 475 : Very easy to use.	1
#
# line 476 : Uncomfortable In the Ear, Don't use with LG VX9900 (EnV).	0
#
# line 477 : The volume switch rocketed out of the unit to a destination unknown.	0
#
# line 478 : It holds a charge for a long time, is reasonably comfortable under long-wearing conditions and the quality of sound is tremendous.	1
#
# line 479 : I'd like to return it.	0
#
# line 480 : The keyboard is really worthwhile in usefulness and is sturdy enough I don't expect any problems.	1
#
# line 481 : Verizon's bills, however, are difficult to understand even though their pricing plans are simple.	0
#
# line 482 : After charging overnight, these batteries work great.	1
#
# line 483 : You won't regret it!	1
#
# line 484 : I love this phone!.	1
#
# line 485 : A Disappointment.	0
#
# line 486 : Its not user friendly.	0
#
# line 487 : Unfortunately the ability to actually know you are receiving a call is a rather important feature and this phone is pitiful in that respect.	0
#
# line 488 : Then I exchanged for the same phone, even that had the same problem.	0
#
# line 489 : This results in the phone being either stuck at max volume or mute.	0
#
# line 490 : This PDA rocks.	1
#
# line 491 : It is super charged up for use as a small hybrid palmtop/camera/cellphone, and excels in those roles.	1
#
# line 492 : I would definitely recommend the Jabra BT250v for those who are looking for comfort, clarity and a great price!	1
#
# line 493 : I had Verizon 2 years ago and really liked their service.	1
#
# line 494 : Pretty piece of junk.	0
#
# line 495 : Plug was the wrong size.	0
#
# line 496 : Works as described.	1
#
# line 497 : Save your money.... I've had this item for 11 months now.	0
#
# line 498 : Bad Purchase.	0
#
# line 499 : WELL IM SATISFIED.	1
#
# line 500 : The bose noise cancelling is amazing, which is very important for a NYC commuter.	1
#
# line 501 : This battery is an excellent bargain!	1
#
# line 502 : Defective crap.	0
#
# line 503 : I would have given no star if I was able.	0
#
# line 504 : I wear glasses and it fits fine with them.	1
#
# line 505 : The sound quality for the device is unacceptable.Unless you are in a really quiet area, you almost hear nothing.	0
#
# line 506 : I would not recommend this item to anyone.	0
#
# line 507 : The holster that arrived did not match the photo in the ad.	0
#
# line 508 : great...no problems at all!.	1
#
# line 509 : As an earlier review noted, plug in this charger and nothing happens.	0
#
# line 510 : This frog phone charm is adorable and very eye catching.	1
#
# line 511 : You never know if you pushed it hard enough or the right number of times for the function you want or not.	0
#
# line 512 : The sound is clear and the people I talk to on it are amazed at the quality too.	1
#
# line 513 : I got the aluminum case for my new Palm VX and it worked really well--it has protected my handheld perfectly so far.	1
#
# line 514 : very good product, well made.	1
#
# line 515 : Mobile Phone Tools are a must have.	1
#
# line 516 : I am very impressed with the job that Motorola did on the sturdiness of this phone.	1
#
# line 517 : I received my orders well within the shipping timeframe, everything was in good working order and overall, I am very excited to have this source.	1
#
# line 518 : The phone is sturdy and waterproof.	1
#
# line 519 : I am not impressed with this and i would not recommend this item to anyone.	0
#
# line 520 : My only complaint is the standard sound volume is a little low even when turned up to 5(of 5)	0
#
# line 521 : Thanks again to Amazon for having the things I need for a good price!	1
#
# line 522 : I ended up sliding it on the edge of my pants or back pockets instead.	1
#
# line 523 : I had to go to a store and bought a new NOKIA phone which is working great.	1
#
# line 524 : Works great!.	1
#
# line 525 : REALLY UGLY.	0
#
# line 526 : horrible, had to switch 3 times.	0
#
# line 527 : The noise shield is incrediable.	1
#
# line 528 : No real improvement.	0
#
# line 529 : Razr Battery - Good buy.	1
#
# line 530 : Keep up the good work Amazon!!	1
#
# line 531 : They refuse to refund or replace.	0
#
# line 532 : Unfortunately it's easy to accidentally activate them with the gentle-touch buttons if you accidentally touch the phone to your face while listening.	0
#
# line 533 : So I basically threw my money out the window for nothing.	0
#
# line 534 : Great case and price!	1
#
# line 535 : All it took was one drop from about 6 inches above the kitchen counter and it was cracked.I am not impressed and I am not laughing.	0
#
# line 536 : Bluetooth range is good - a few days ago I left my phone in the trunk, got a call, and carried the conversation without a hitch.	1
#
# line 537 : Small, sleek, impressive looking, practical setup with ample storage in place.	1
#
# line 538 : The eargels channel the sound directly into your ear and seem to increase the sound volume and clarity.	1
#
# line 539 : none of the new ones have ever quite worked properly.	0
#
# line 540 : I am glad I purchased it.	1
#
# line 541 : I've missed numerous calls because of this reason.	0
#
# line 542 : Perhaps my phone is defective, but people cannot hear me when I use this.	0
#
# line 543 : Don't buy this product.	0
#
# line 544 : sucked, most of the stuff does not work with my phone.	0
#
# line 545 : No shifting, no bubbling, no peeling, not even a scratch, NOTHING!I couldn't be more happier with my new one for the Droid.	1
#
# line 546 : Worst software ever used.... If I could give this zero stars I would.	0
#
# line 547 : Trying to make a call on these is an exercise in frustration.	0
#
# line 548 : The case is a flimsy piece of plastic and has no front or side protection whatsoever.	0
#
# line 549 : I own a Jabra Earset and was very happy with it, but the sound quality, especially outgoing, on this is better.	1
#
# line 550 : I love the camera, it's really pretty good quality.	1
#
# line 551 : Thank you for such great service.	1
#
# line 552 : Its a total package.	1
#
# line 553 : The seller is very understanding and patient, I would definitely buy from them again.	1
#
# line 554 : I give Wirefly 1 star.I will contact Cingular/AT&T; and inform them of this practice.	0
#
# line 555 : It's AGGRAVATING!	0
#
# line 556 : Great product for the price!.	1
#
# line 557 : I have purchased these for both family and friends, and all enjoy their clarity and ease of use	1
#
# line 558 : Virgin Wireless rocks and so does this cheap little phone!	1
#
# line 559 : None of it works, just don't buy it.	0
#
# line 560 : Muddy, low quality sound, and the casing around the wire's insert was poorly super glued and slid off.	0
#
# line 561 : Please dont waste your money.	0
#
# line 562 : All in all, I'm quite satisfied with this purchase.	1
#
# line 563 : If you are looking for a good quality Motorola Headset keep looking, this isn't it.	0
#
# line 564 : Yet Plantronincs continues to use the same flawed charger design.	0
#
# line 565 : Disapointing Results.	0
#
# line 566 : Cumbersome design.	0
#
# line 567 : Great it was new packaged nice works good, no problems and it came in less time then I expected!!!!	1
#
# line 568 : Great Product.	1
#
# line 569 : It's A PIECE OF CRAP!	0
#
# line 570 : My experience was terrible..... This was my fourth bluetooth headset, and while it was much more comfortable than my last Jabra (which I HATED!!!	0
#
# line 571 : This fixes all the problems.	1
#
# line 572 : Worst ever.	0
#
# line 573 : I am very happy	1
#
# line 574 : I've had no trouble accessing the Internet, downloading ringtones or performing any of the functions.	1
#
# line 575 : I can barely ever hear on it and am constantly saying "what?"	0
#
# line 576 : The battery life is highly unacceptable.	0
#
# line 577 : That company is a joke.	0
#
# line 578 : It does everything the description said it would.	1
#
# line 579 : Due to this happening on every call I was forced to stop using this headset.	0
#
# line 580 : It works great with a car charger, especially if you cannot plug in two adapters at the same time.	1
#
# line 581 : Verizon tech support walked my through a few procedures, none of which worked and I ended up having to do a hard re-set, wiping out all my data.	0
#
# line 582 : Voice Quality, Signal Strength, Dropped Calls.	0
#
# line 583 : It plays louder than any other speaker of this size; the price is so low that most would think the quality is lacking, however, it's not.	1
#
# line 584 : Better than expected.	1
#
# line 585 : It feels poorly constructed, the menus are difficult to navigate, and the buttons are so recessed that it is difficult to push them.	0
#
# line 586 : Battery is holding up well.	1
#
# line 587 : Also difficult to put on.I'd recommend avoiding this product.	0
#
# line 588 : I only used it two days, and it wasn't always easy to hear with.	0
#
# line 589 : I got the car charger and not even after a week the charger was broken...I went to plug it in and it started smoking.	0
#
# line 590 : Sprint - terrible customer service.	0
#
# line 591 : Linked to my phone without effort.	1
#
# line 592 : THey are so cool!	1
#
# line 593 : Easy to use.	1
#
# line 594 : Better Than New.	1
#
# line 595 : What possesed me to get this junk, I have no idea...	0
#
# line 596 : Piece of trash.	0
#
# line 597 : A pretty good product.	1
#
# line 598 : This is a great phone!.	1
#
# line 599 : For the price on Amazon, it is an excellent product, which I would highly recommend.	1
#
# line 600 : Their Research and Development division obviously knows what they're doing.	1
#
# line 601 : The real killer is the volume, and of course it breaking.	0
#
# line 602 : Those phones are working just fine now.	1
#
# line 603 : I am more than happy with this product.	1
#
# line 604 : Poor Construction.	0
#
# line 605 : This is infuriating.	0
#
# line 606 : Overall, I would recommend this phone over the new Walkman.	1
#
# line 607 : Sprint charges for this service.	0
#
# line 608 : It is cheap, and it feel and look just as cheap.	0
#
# line 609 : It fits my ear well and is comfortable on.	1
#
# line 610 : It doesn't work in Europe or Asia.	0
#
# line 611 : clipping this to your belt will deffinitely make you feel like 50 cent's up-and-coming.	1
#
# line 612 : I like design and look of Jabra behing the ear headsets and 5020 is pretty comfortible to wear 24 hours a day without pain in the ear.	1
#
# line 613 : I was amazed at the quick arrival of the two original lg cell phone batteries and and at a fraction of the price.	1
#
# line 614 : the worst phone from samsung...crap..... this crappy Samsung E715.. is the worst i have ever seeen.	0
#
# line 615 : the charger worked for about a week and then completely stopped charging my phone.	0
#
# line 616 : Poor product.	0
#
# line 617 : However I needed some better instructions.	0
#
# line 618 : You need two hands to operate the screen.This software interface is decade old and cannot compete with new software designs.	0
#
# line 619 : Worked very well paired with a Treo 700w and as a Skype headset on my PC (using a USB Bluetooth transceiver).	1
#
# line 620 : Steer clear of this product and go with the genuine Palm replacementr pens, which come in a three-pack.	0
#
# line 621 : DO NOT BUY DO NOT BUYIT SUCKS	0
#
# line 622 : This is a great product..... sure beats using your fingers!.	1
#
# line 623 : Plus, I seriously do not believe it is worth its steep price point.	0
#
# line 624 : All the other cases I've tried normally fall apart after a few months but this one seems to be in for the long haul.	1
#
# line 625 : Very Dissapointing Performance.	0
#
# line 626 : Don't make the same mistake that I did and please don't buy this phone.	0
#
# line 627 : This phone might well be the worst I've ever had in any brand.	0
#
# line 628 : Case was more or less an extra that I originally put on but later discarded because it scratched my ear.	0
#
# line 629 : I recommend iGo to anyone with different brand cell phones/mp3 players in the family.	1
#
# line 630 : Don't bother - go to the store.	0
#
# line 631 : I posted more detailed comments under the grey or black phone, but i have the Fire Red and it's a great color!	1
#
# line 632 : I did not have any problem with this item and would order it again if needed.	1
#
# line 633 : You get what you pay for I guess.	0
#
# line 634 : Not only did the software do a great job of this, I could also make my own ringtones form my existing CDs without an internet connection.	1
#
# line 635 : im surprised this is a good quality car charger and there's not much reviews about it.	1
#
# line 636 : These are fabulous!	1
#
# line 637 : However, BT headsets are currently not good for real time games like first-person shooters since the audio delay messes me up.	0
#
# line 638 : I used bitpim (a free program you can find on the internet)to transfer data to the phone.The price of the cable was excellent.	1
#
# line 639 : Disappointing accessory from a good manufacturer.	0
#
# line 640 : Performed awful -- muffled, tinny incoming sound and severe echo for those on the other end of the call.	0
#
# line 641 : Very wind-resistant.	1
#
# line 642 : Obviously they have a terrible customer service, so you get what you pay for.	0
#
# line 643 : They do not last forever, but is not overly expensive to replace.Easy to operate and the sound is much better than others I have tried.	1
#
# line 644 : I contacted the company and they told me that, although the unit was still under warranty, if I couldn't produce my receipt I was out of luck.	0
#
# line 645 : Linksys should have some way to exchange a bad phone for a refurb unit or something!	0
#
# line 646 : Phone is sturdy as all nokia bar phones are.	1
#
# line 647 : Great phone.	1
#
# line 648 : When I placed my treo into the case, not only was it NOT snug, but there was A LOT of extra room on the sides.	0
#
# line 649 : I'm pleased.	1
#
# line 650 : Battery is terrible.	0
#
# line 651 : I found the product to be easy to set up and use.	1
#
# line 652 : The earpiece on this is too large or too heavy...it keeps falling out of my ear.	0
#
# line 653 : Utter crap.. Sound quality is TERRIBLE.	0
#
# line 654 : The charger arrived within the promised timeframe, but it did not work.	0
#
# line 655 : No ear loop needed, it's tiny and the sound is great.	1
#
# line 656 : Finally, after three or four times the spring of the latch broke and I could not use it any longer on the visor.	0
#
# line 657 : The handsfree part works fine, but then the car tries to download the address book, and the Treo reboots.Overall, I still rate this device high.	1
#
# line 658 : Talk about USELESS customer service.	0
#
# line 659 : It felt too light and "tinny.".	0
#
# line 660 : This does not fit the Palm Tungsten E2 and it broke the first time I tried to plug it in.	0
#
# line 661 : I'm happy about this purchase- good quality and low price.	1
#
# line 662 : I love the look and feel of Samsung flipphones.	1
#
# line 663 : Its well-designed and very sharp -- the blue is a very nice color.	1
#
# line 664 : Does everything it should and more.	1
#
# line 665 : I could not recommend these more.	0
#
# line 666 : Nice Sound.	1
#
# line 667 : Looks good in the picture, but this case was a huge disappointment!!	0
#
# line 668 : Much less than the jawbone I was going to replace it with.	1
#
# line 669 : Setup went very smoothly.	1
#
# line 670 : its extremely slow and takes forever to do anything with it.	0
#
# line 671 : A must study for anyone interested in the "worst sins" of industrial design.	0
#
# line 672 : The first thing that happened was that the tracking was off.	0
#
# line 673 : It is well made, easy to access the phone and has a handy, detachable belt clip.	1
#
# line 674 : Then I had to continue pairing it periodically since it somehow kept dropping.	0
#
# line 675 : Can't upload ringtones from a third party.	0
#
# line 676 : Bluetooth does not work, phone locks up, screens just flash up and now it just makes calls randomly while in my pocket locked.	0
#
# line 677 : Truly awful.	0
#
# line 678 : It works fine on my Motorola 325 cellphone, and a lot better than the worn-out battery did.	1
#
# line 679 : The volume for the ringer is REAL good (you have choices how loud).	1
#
# line 680 : And none of the tones is acceptable.	0
#
# line 681 : camera color balance is AWFUL.	0
#
# line 682 : This product is clearly not ready for prime time, I don't care how cool it looks, if you can't tell a call is coming in it's worthless.	0
#
# line 683 : I love the ringtones because they are so upbeat!	1
#
# line 684 : Chinese Forgeries Abound!.	0
#
# line 685 : Easy to pair with my Samsung Cell.	1
#
# ...
#
# line 764 : wont work right or atleast for me.	0
#
# line 765 : in addition it feels &amp; looks as if the phone is all lightweight cheap plastic.	0
#
# line 766 : But now that it is "out of warranty" the same problems reoccure.Bottom line... put your money somewhere else... Cingular will not support it.	0
#
# line 767 : I really wanted the Plantronics 510 to be the right one, but it has too many issues for me.The good	0
#
# line 768 : Great product.	1
#
# line 769 : Crisp and Clear.	1
#
# line 770 : AFter the first charge kept going dead after 12 minutes.	0
#
# line 771 : VERY cheap plastic, creaks like an old wooden floor.	0
#
# line 772 : I get absolutely horrible reception in my apartment, where with other phones I have not had this problem.	0
#
# line 773 : The reception has been generally good.	1
#
# line 774 : Excellent sound, battery life and inconspicuous to boot!.	1
#
# line 775 : Great bluetooth!.	1
#
# line 776 : I highly recommend this case.	1
#
# line 777 : WORTHWHILE.	1
#
# line 778 : This is a great deal.	1
#
# line 779 : After my phone got to be about a year old, it's been slowly breaking despite much care on my part.	0
#
# line 780 : I am sorry I made this purchase.	0
#
# line 781 : I bought these hoping I could make my Bluetooth headset fit better but these things made it impossible to wear.	0
#
# line 782 : Treo and T-Mobile refused to replace it again and forced me to buy another phone without any kind of upgrade discount.	0
#
# line 783 : It was horrible!.	0
#
# line 784 : I don't think it would hold it too securly on your belt.	0
#
# line 785 : This allows the possibility of double booking for the same date and time after the first.	0
#
# line 786 : They work about 2 weeks then break.	0
#
# line 787 : It is simple to use and I like it.	1
#
# line 788 : It's a great tool for entertainment, communication, and data management.Oh, be sure to use ActiveSync 4.2 for optimal data synchronization results!	1
#
# line 789 : I can't use this case because the smell is disgusting.	0
#
# line 790 : NOT WHAT I WANTED.	0
#
# line 791 : I own 2 of these cases and would order another.	1
#
# line 792 : Great Phone.	1
#
# line 793 : I bought this battery with a coupon from Amazon and I'm very happy with my purchase.	1
#
# line 794 : The internet access was fine, it the rare instance that it worked.	0
#
# line 795 : Perfect for the PS3.	1
#
# line 796 : Five star Plus, plus.	1
#
# line 797 : A good quality bargain.. I bought this after I bought a cheapy from Big Lots that sounded awful and people on the other end couldn't hear me.	1
#
# line 798 : $50 Down the drain.	0
#
# line 799 : I tried talking real loud but shouting on the telephone gets old and I was still told it wasn't great.	0
#
# line 800 : Good , works fine.	1
#
# line 801 : For the price this was a great deal.	1
#
# line 802 : Great price, too!	1
#
# line 803 : If there is a wind, it is completely useless.	0
#
# line 804 : Yes it's shiny on front side - and I love it!	1
#
# line 805 : Does Not Work.	0
#
# line 806 : At first I thought I was grtting a good deal at $7.44, until I plugged it into my phone (V3c Razr).	0
#
# line 807 : The reception through this headset is excellent.	1
#
# line 808 : 2 thumbs up to this seller	1
#
# line 809 : I have a Verizon LG phone and they work well together, good reception and range that exceeds 20 feet line of sight.	1
#
# line 810 : Improper description.... I had to return it.	0
#
# line 811 : #1 It Works - #2 It is Comfortable.	1
#
# line 812 : Battery charge-life is quite long.	1
#
# line 813 : The Jabra EarGels fit my ears very well.	1
#
# line 814 : Battery has no life.	0
#
# line 815 : I checked everywhere and there is no feature for it which is really disappointing.	0
#
# line 816 : Product is exactly as described.	1
#
# line 817 : Gets a signal when other Verizon phones won't.	1
#
# line 818 : Doesn't do the job.	0
#
# line 819 : I would recommend it.	1
#
# line 820 : Plan on ordering from them again and again.	1
#
# line 821 : That being said, for a phone, the camera is very nice; many cool effects to play with, and video is decent as well.	1
#
# line 822 : I have been very satisfied with this cell phone from day one.	1
#
# line 823 : They keep getting better and better (this is my third one and I've had numerous Palms too).	1
#
# line 824 : Awkward to use and unreliable.	0
#
# line 825 : The shipping time was also very quick!	1
#
# line 826 : Not as good as I had hoped.	0
#
# line 827 : Good case!.	1
#
# line 828 : Doesn't Work.	0
#
# line 829 : Really good product.	1
#
# line 830 : Unfortunately it did not work.	0
#
# line 831 : All three broke within two months of use.	0
#
# line 832 : dont buy it.	0
#
# line 833 : My father has the V265, and the battery is dying.	0
#
# line 834 : However, the ear pads come off easily and after only one week I lost one.	0
#
# line 835 : The calls drop, the phone comes on and off at will, the screen goes black and the worst of all it stops ringing intermittently.	0
#
# line 836 : Horrible, horrible protector.	0
#
# line 837 : I don't like this Nokia either.	0
#
# line 838 : Reaching for the bottom row is uncomfortable, and the send and end keys are not where I expect them to be.3.	0
#
# line 839 : I have bought this Nokia cell phone a few weeks ago and it was a nightmare.	0
#
# line 840 : It would take too long to describe how bad my customer service experience has been with Amazon.	0
#
# line 841 : the only VERY DISAPPOINTING thing was there was NO SPEAKERPHONE!!!!	0
#
# line 842 : Terrible.. My car will not accept this cassette.	0
#
# line 843 : Product is useless, since it does not have enough charging current to charge the 2 cellphones I was planning to use it with.	0
#
# line 844 : It's not what it says it is.	0
#
# line 845 : Stay Away From the Q!.	0
#
# line 846 : Used and dirty.	0
#
# line 847 : Very unreliable service from T-mobile !	0
#
# line 848 : Not good enough for the price.	0
#
# line 849 : I bought two of them and neither will charge.	0
#
# line 850 : It looks very nice.	1
#
# line 851 : This is an excellent tool, especially when paired with your phone's auto-answer.	1
#
# line 852 : I have read other's reviews here but I haven't had any problem with it.	1
#
# line 853 : These products cover up the important light sensor above the ear outlet.	0
#
# line 854 : Comfortable in my hand.	1
#
# line 855 : Just does not work.	0
#
# line 856 : Poor Reliability.	0
#
# line 857 : (It works!)	1
#
# line 858 : If I take a picture, the battery drops a bar, and starts beeping, letting me know its dieing.	0
#
# line 859 : Terrible product, and waste of money!	0
#
# line 860 : Last time buying from you.	0
#
# line 861 : It was a waste of my money.	0
#
# line 862 : So far it has worked like a charm.	1
#
# line 863 : I have only had it for a few weeks, but so far, so good.	1
#
# line 864 : But, in any case, the best part is, you can download these pictures to your laptop using IR, or even send pictures from your laptop to the phone.	1
#
# line 865 : Would recommend this item.	1
#
# line 866 : It's been my choice headset for years.Great sound; good volume; good noise cancellation.	1
#
# line 867 : Nice case, feels good in your hands.	1
#
# line 868 : The item received was Counterfeit.	0
#
# line 869 : Just really good.. So far, probably the best BT headset I have ever had.	1
#
# line 870 : Works fine.	1
#
# line 871 : I received my headset in good time and was happy with it.	1
#
# line 872 : I was very pleased to see that I could replace my well travled swivel holster for my Blackberry flip.	1
#
# line 873 : My sister has one also and she loves it.	1
#
# line 874 : Good Quality.	1
#
# line 875 : This is by far the worst purchase I've made on Amazon.	0
#
# line 876 : Excellent dual-purpose headset.	1
#
# line 877 : Excellent!.	1
#
# line 878 : Does not work for listening to music with the cingular 8125.	0
#
# line 879 : It seems completely secure, both holding on to my belt, and keeping the iPhone inside.	1
#
# line 880 : The bottowm line...another worthless, cheap gimmick from Sprint.	0
#
# line 881 : Having trouble with volume.	0
#
# line 882 : The only good thing was that it fits comfortably on small ears.	1
#
# line 883 : WARNING - DO NOT BUY!!.	0
#
# line 884 : I am pairing this with my iphone, and I could not be happier with it so far.	1
#
# line 885 : When it opens, the battery connection is broken and the device is turned off.	0
#
# line 886 : I didn't want the clip going over the top of my ear, causing discomfort.	0
#
# line 887 : Best headset ever!!!.	1
#
# line 888 : Don't trust their website and don't expect any helpful support.	0
#
# line 889 : It was that loud.Glad to say that the Plantronics 510 maintains a flawless connection to my cell and with no static during normal use.	1
#
# line 890 : The speaker is of low quality so as making the ring tones sound very cheap.	0
#
# line 891 : Fits comfortably, came with three sizes of earbud tips.	1
#
# line 892 : Excellent product for the price.	1
#
# line 893 : Bad Reception.	0
#
# line 894 : This product is very High quality Chinese CRAP!!!!!!	0
#
# line 895 : It was quite comfortable in the ear.	1
#
# line 896 : Great phone.	1
#
# line 897 : Don't buy this product - It fails!.	0
#
# line 898 : Everything about this product is wrong.First	0
#
# line 899 : The pairing of the two devices was so easy it barely took a couple minutes before I started making calls with the voice dialing feature.	1
#
# line 900 : This was utterly confusing at first, which caused me to lose a couple of very, very important contacts.	0
#
# line 901 : Terrible phone holder.	0
#
# line 902 : The cutouts and buttons are placed perfectly.	1
#
# line 903 : I love being able to use one headset for both by land-line and cell.	1
#
# line 904 : Problem is that the ear loops are made of weak material and break easily.	0
#
# line 905 : Not nearly as good looking as the AMAZON picture makes it look.	0
#
# line 906 : But despite these few flaws, this case is of exceptional quality and well worth the additional costs of owning an official OEM product.	1
#
# line 907 : How stupid is that?	0
#
# line 908 : I can hear while I'm driving in the car, and usually don't even have to put it on it's loudest setting.	1
#
# line 909 : Seller shipped quickly and much cheaper than the competitors.	1
#
# line 910 : Good show, Samsung.	1
#
# line 911 : So I bought about 10 of these and saved alot of money.	1
#
# line 912 : It always cuts out and makes a beep beep beep sound then says signal failed.	0
#
# line 913 : Couldn't figure it out	0
#
# line 914 : My phone sounded OK ( not great - OK), but my wife's phone was almost totally unintelligible, she couldn't understand a word being said on it.	0
#
# line 915 : So I had to take the battery out of the phone put it all back together and then restart it.	0
#
# line 916 : While I managed to bend the leaf spring back in place, the metal now has enough stress that it will break on the next drop.	0
#
# line 917 : Leopard Print is wonderfully wild!.	1
#
# line 918 : Works for me.	1
#
# line 919 : Saggy, floppy piece of junk.	0
#
# line 920 : much better than the hard plastic cases.	1
#
# line 921 : It also had a new problem.	0
#
# line 922 : Happy so far!.	1
#
# line 923 : cool phone.	1
#
# line 924 : Works good.	1
#
# line 925 : Motorola finally got the voice quality of a bluetooth headset right.	1
#
# line 926 : It looses connection to the phone even when it is within a couple feet between the two.	0
#
# line 927 : but it is great, i would really recommend it	1
#
# line 928 : Makes it easier to keep up with my bluetooth when I'm not wearing it.	0
#
# line 929 : As I said above....PRETTY USELESS!	0
#
# line 930 : Never got it!!!!!	0
#
# line 931 : This pair of headphones is the worst that I have ever had sound-wise.	0
#
# line 932 : [...] down the drain because of a weak snap!	0
#
# line 933 : Does not charge the Cingular (ATT) 8525 phone.	0
#
# line 934 : You get extra minutes so that you can carry out the call and not get cut off."	1
#
# line 935 : However, after about a year, the fliptop started to get loose and wobbly and eventually my screen went black and I couldn't receive and place calls.	0
#
# line 936 : I kept catching the cable on the seat and I had to pull the phone out to turn it on an off.	0
#
# line 937 : The headset fulfills my requirements so I am happy with my purchase.	1
#
# line 938 : Logitech Bluetooth Headset is a 10!.	1
#
# line 939 : I like the fact that it rests lightly against your ear, rather than inside.	1
#
# line 940 : A lot of websites have been rating this a very good phone and so do I.	1
#
# line 941 : I have tried these cables with my computer and my iPod and it works just fine.	1
#
# line 942 : The mic there is a joke, and the volume is quite low.	0
#
# line 943 : I'm returning them.	0
#
# line 944 : I does not maintain a connection with the computer while it is on my lap.	0
#
# line 945 : It is easy to turn on and off when you are in the car and the volume controls are quite accessable.	1
#
# line 946 : I have had mine for about a year and this Christmas I bought some for the rest of the family.	1
#
# line 947 : Otherwise, easy to install and use, clear sound.	1
#
# line 948 : nice leather.	1
#
# line 949 : I had to purchase a different case.	0
#
# line 950 : It is a joy to use.	1
#
# line 951 : Very much disappointed with this company.	0
#
# line 952 : Very satisifed with that.	1
#
# line 953 : It didn't charge for me.	0
#
# line 954 : This is the phone to get for 2005.... I just bought my S710a and all I can say is WOW!	1
#
# line 955 : Buttons are too small.	0
#
# line 956 : Just reading on the specs alone makes you say WOW.	1
#
# line 957 : Love it.. Great armband.	1
#
# line 958 : I really like this product over the Motorola because it is allot clearer on the ear piece and the mic.	1
#
# line 959 : However, the keypads are so tinny that I sometimes reach the wrong buttons.	0
#
# line 960 : I exchanged the sony ericson z500a for this and I'm pretty happy with that decision.	1
#
# line 961 : I was very impressed with the price of the cases.	1
#
# line 962 : Also makes it easier to hold on to.	1
#
# line 963 : I use this product in a motor control center where there is a lot of high voltage humming from the equipment, and it works great!	1
#
# line 964 : It's pretty easy.	1
#
# line 965 : I cannot make calls at certain places.	0
#
# line 966 : however, my girl was complain that some time the phone doesn't wake up like normal phone does.	0
#
# line 967 : Beautiful styling though.	1
#
# line 968 : This company charge me a restocking fee and still not given me my refund back.	0
#
# line 969 : I'm trying to return it for a refund.	0
#
# line 970 : I plugged it in only to find out not a darn thing worked.	0
#
# line 971 : Excellent product.	1
#
# line 972 : Earbud piece breaks easily.	0
#
# line 973 : Lousy product.	0
#
# line 974 : This phone tries very hard to do everything but fails at it's very ability to be a phone.	0
#
# line 975 : It is the best charger I have seen on the market yet.	1
#
# line 976 : SWEETEST PHONE!!!	1
#
# line 977 : :-)Oh, the charger seems to work fine.	1
#
# line 978 : It fits so securely that the ear hook does not even need to be used and the sound is better directed through your ear canal.	1
#
# line 979 : Not enough volume.	0
#
# line 980 : Echo Problem....Very unsatisfactory	0
#
# line 981 : you could only take 2 videos at a time and the quality was very poor.	0
#
# line 982 : don't waste your money.	0
#
# line 983 : I am going to have to be the first to negatively review this product.	0
#
# line 984 : Adapter does not provide enough charging current.	0
#
# line 985 : There was so much hype over this phone that I assumed it was the best, my mistake.	0
#
# line 986 : You also cannot take pictures with it in the case because the lense is covered.	0
#
# line 987 : Phone falls out easily.	0
#
# line 988 : It didn't work, people can not hear me when I talk.	0
#
# line 989 : The text messaging feature is really tricky to use.	0
#
# line 990 : I'm really disappointed all I have now is a charger that doesn't work.	0
#
# line 991 : Painful on the ear.	0
#
# line 992 : Lasted one day and then blew up.	0
#
# line 993 : disappointed.	0
#
# line 994 : Kind of flops around.	0
#
# line 995 : The screen does get smudged easily because it touches your ear and face.	0
#
# line 996 : What a piece of junk.. I lose more calls on this phone.	0
#
# line 997 : Item Does Not Match Picture.	0
#
# line 998 : The only thing that disappoint me is the infra red port (irda).	0
#
# line 999 : You can not answer calls with the unit, never worked once!	0

# %%
def getVocubulary(fp):
    result=fp.read()
    words=sorted(set(re.split(r"\W+",result)))
    words=[word.lower() for word in words]
    return words

# %%
def positiveClass(line):
    positivelinecount=0
    positive_class=[]
    words_in_line = line.split()
    if(words_in_line[-1]=='1'):
        positivelinecount+=1
        #print(line)
        positive_class.append(line)
        return positive_class

# %%
def negativeClass(line):
    negative_class=[] 
    words_in_line = line.split()
    if(words_in_line[-1]=='0'):
        #print(line)
        negative_class.append(line)
        return negative_class

# %%
def getVocubulary(fp):
    result=fp.read()
    words=sorted(set(re.split(r"\W+",result)))
    words=[word.lower() for word in words]
    return words

# %%
def order_bag_of_words(bag_of_words, desc=False):  
   words = [(word, count) for word, count in bag_of_words.items()]
   return sorted(words, key=lambda x: x[1], reverse=desc)

# %%
def record_word_count(words, bag_of_words):  
   for word in words:
       if word != '':
           #print(word)
           if word.lower() in bag_of_words:
                
               bag_of_words[word.lower()] += 1
           else:
               bag_of_words[word.lower()] = 1

# %%
#calculate the log prior (probability of each class)
def calculateClassProbabilities(trainingSet):
    positive_prob = np.log(len(trainingSet[0])/(len(trainingSet[0])+len(trainingSet[1])))
    negative_prob = np.log(len(trainingSet[1])/(len(trainingSet[0])+len(trainingSet[1])))
    return positive_prob, negative_prob

# %%
def accuracyTest(testingSet):
        data = []
        for i in range (len(testingSet)):
            if self.testingSet[i][1]== self.testingSet[i][1]:
                data.append(1)
            else:
                pass
        return(round((sum(data)/len(self.testingSet))*100))

# %%
if __name__ == '__main__':  
   main()
